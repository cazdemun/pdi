# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = cv2.imread('P6070006.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20, 10))
plt.imshow(img_rgb)
plt.show()

white = np.uint8([[[255,255,255]]])
white_hsv = cv2.cvtColor(white, cv2.COLOR_RGB2HSV)

lower_white = np.array([0, 0, 150])
upper_white = np.array([10, 255, 230])

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(img_hsv, lower_white, upper_white)
mask = cv2.GaussianBlur(mask, (3,3), 0)

res = cv2.bitwise_and(img_rgb, img_rgb, mask = mask)

plt.figure(figsize=(20, 10))
plt.imshow(res)
plt.show()

row, col, _ = img.shape
pad = col - row

x = cv2.getGaussianKernel(row, 100)
gaussian = x * x.T
superGaussian = gaussian

for i in range(0, row):
    for j in range(0, row):
        if gaussian[i][j] < 0.000005:
            superGaussian[i][j] = 0
        else:
            superGaussian[i][j] = 1

mask = np.zeros((row, col))
mask[:row,pad//2:pad//2+row] = superGaussian

# Applying filters
img_gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
img_gray = img_gray * mask
# Printing
plt.figure(figsize=(20, 10))
plt.imshow(img_gray, 'gray')
plt.show()

c0, c1 = col, 0
r0, r1 = row, 0

for i in range(0, row):
    for j in range(0, col):
        if j < c0 and img_gray[i][j] != 0:
            c0 = j
        if j > c1 and img_gray[i][j] != 0:
            c1 = j
        if i < r0 and img_gray[i][j] != 0:
            r0 = i
        if i > r1 and img_gray[i][j] != 0:
            r1 = i

recortado = img_rgb[r0:r1,c0:c1]
plt.figure(figsize=(20, 10))
plt.imshow(recortado)
plt.show()

# %%
img = cv2.imread('P6070007.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20, 10))
plt.imshow(img_rgb)
plt.show()

white = np.uint8([[[255,255,255]]])
white_hsv = cv2.cvtColor(white, cv2.COLOR_RGB2HSV)

lower_white = np.array([0, 0, 180])
upper_white = np.array([10, 255, 255])

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(img_hsv, lower_white, upper_white)
mask = cv2.GaussianBlur(mask, (3,3), 0)

res = cv2.bitwise_and(img_rgb, img_rgb, mask = mask)

plt.figure(figsize=(20, 10))
plt.imshow(res)
plt.show()

row, col, _ = img.shape
pad = col - row

x = cv2.getGaussianKernel(row, 100)
gaussian = x * x.T
superGaussian = gaussian

for i in range(0, row):
    for j in range(0, row):
        if gaussian[i][j] < 0.000005:
            superGaussian[i][j] = 0
        else:
            superGaussian[i][j] = 1

mask = np.zeros((row, col))
mask[:row,pad//2:pad//2+row] = superGaussian

# Applying filters
img_gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
img_gray = img_gray * mask
# Printing
plt.figure(figsize=(20, 10))
plt.imshow(img_gray, 'gray')
plt.show()

c0, c1 = col, 0
r0, r1 = row, 0

for i in range(0, row):
    for j in range(0, col):
        if j < c0 and img_gray[i][j] != 0:
            c0 = j
        if j > c1 and img_gray[i][j] != 0:
            c1 = j
        if i < r0 and img_gray[i][j] != 0:
            r0 = i
        if i > r1 and img_gray[i][j] != 0:
            r1 = i

recortado = img_rgb[r0:r1,c0:c1]
plt.figure(figsize=(20, 10))
plt.imshow(recortado)
plt.show()

# %%
img = cv2.imread('P6070010.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20, 10))
plt.imshow(img_rgb)
plt.show()

white = np.uint8([[[255,255,255]]])
white_hsv = cv2.cvtColor(white, cv2.COLOR_RGB2HSV)

lower_white = np.array([0, 0, 180])
upper_white = np.array([10, 255, 255])

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(img_hsv, lower_white, upper_white)
mask = cv2.GaussianBlur(mask, (3,3), 0)

res = cv2.bitwise_and(img_rgb, img_rgb, mask = mask)

plt.figure(figsize=(20, 10))
plt.imshow(res)
plt.show()

row, col, _ = img.shape
pad = col - row

x = cv2.getGaussianKernel(row, 100)
gaussian = x * x.T
superGaussian = gaussian

for i in range(0, row):
    for j in range(0, row):
        if gaussian[i][j] < 0.000005:
            superGaussian[i][j] = 0
        else:
            superGaussian[i][j] = 1

mask = np.zeros((row, col))
mask[:row,pad//2:pad//2+row] = superGaussian

# Applying filters
img_gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
img_gray = img_gray * mask
# Printing
plt.figure(figsize=(20, 10))
plt.imshow(img_gray, 'gray')
plt.show()

c0, c1 = col, 0
r0, r1 = row, 0

for i in range(0, row):
    for j in range(0, col):
        if j < c0 and img_gray[i][j] != 0:
            c0 = j
        if j > c1 and img_gray[i][j] != 0:
            c1 = j
        if i < r0 and img_gray[i][j] != 0:
            r0 = i
        if i > r1 and img_gray[i][j] != 0:
            r1 = i

recortado = img_rgb[r0:r1,c0:c1]
plt.figure(figsize=(20, 10))
plt.imshow(recortado)
plt.show()

# %%
img = cv2.imread('P6070011.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20, 10))
plt.imshow(img_rgb)
plt.show()

white = np.uint8([[[255,255,255]]])
white_hsv = cv2.cvtColor(white, cv2.COLOR_RGB2HSV)

lower_white = np.array([0, 0, 180])
upper_white = np.array([10, 255, 255])

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(img_hsv, lower_white, upper_white)
mask = cv2.GaussianBlur(mask, (3,3), 0)

res = cv2.bitwise_and(img_rgb, img_rgb, mask = mask)

plt.figure(figsize=(20, 10))
plt.imshow(res)
plt.show()

row, col, _ = img.shape
pad = col - row

x = cv2.getGaussianKernel(row, 100)
gaussian = x * x.T
superGaussian = gaussian

for i in range(0, row):
    for j in range(0, row):
        if gaussian[i][j] < 0.000005:
            superGaussian[i][j] = 0
        else:
            superGaussian[i][j] = 1

mask = np.zeros((row, col))
mask[:row,pad//2:pad//2+row] = superGaussian

# Applying filters
img_gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
img_gray = img_gray * mask
# Printing
plt.figure(figsize=(20, 10))
plt.imshow(img_gray, 'gray')
plt.show()

c0, c1 = col, 0
r0, r1 = row, 0

for i in range(0, row):
    for j in range(0, col):
        if j < c0 and img_gray[i][j] != 0:
            c0 = j
        if j > c1 and img_gray[i][j] != 0:
            c1 = j
        if i < r0 and img_gray[i][j] != 0:
            r0 = i
        if i > r1 and img_gray[i][j] != 0:
            r1 = i

recortado = img_rgb[r0:r1,c0:c1]
plt.figure(figsize=(20, 10))
plt.imshow(recortado)
plt.show()
