# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
def printImg(a, b):
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1), plt.imshow(a, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(b, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def inverseFourier(spectrum):
    img_back = np.fft.ifftshift(spectrum)
    img_back = np.fft.ifft2(img_back)
    img_back = np.abs(img_back)
    return img_back

def fourier(img):
    f = np.fft.fft2(img)
    f = np.fft.fftshift(f)
    return f

def gaussianOne(size, intensity, img):
    rows, cols = img.shape
    crow, ccol = rows // 2, cols // 2
    x = cv2.getGaussianKernel(size * 2, 300)
    gaussian = x * x.T
    mask2 = np.ones((rows, cols))
    mask2[crow - size:crow + size, ccol-size:ccol+size] = gaussian
    return mask2

def gaussianZero(size, intensity, img, crow, ccol):
    rows, cols = img.shape
    #crow, ccol = rows // 2, cols // 2
    x = cv2.getGaussianKernel(size * 2, intensity)
    gaussian = x * x.T
    mask2 = np.zeros((rows, cols))
    mask2[crow - size:crow + size, ccol-size:ccol+size] = gaussian
    return mask2

def drange(start, stop, step):
    r = start
    while r < stop:
        yield r
        r += step

# %%
# Load image and its frequency spectrum
img = cv2.imread('MHcHVmX.png', 0)

f = fourier(img)

magnitud = np.log(1 + np.abs(f))

printImg(img, magnitud)
print(img.shape)
# Out:
# (474, 630)

# %%
i0 = drange(0.0, 2 * np.pi, 0.1)



rows, cols = img.shape
crow, ccol = rows // 2, cols // 2 # center row, center column

# Modifying spectrum
mask = np.zeros((rows, cols), np.uint8)
## Removing vertical and horizontal high frequencies

for t in [ x for x in i0]:
    for r in range (1, 200):
        mask[crow + int(np.sin(t)*r)][ccol + int(np.cos(t)*r)] = 1

#n = 5
#mask[0 : rows, ccol - n : ccol + n] = 0
#mask[0 : rows, ccol // 2 + 20 - n : ccol // 2 + 20 + n] = 0
#mask[0 : rows, ccol + 65 - n : ccol + n + 65] = 0
#mask[crow - n : crow + n, 0 : cols] = 0
#mask[crow // 2 - n : crow // 2 + n, 0 : cols] = 0
#mask[ crow + 60 - n : crow + 60 + n, 0 : cols] = 0

        
## Center correction
#n2 = 10
#mask[crow - n2 : crow + n2, ccol-n2 : ccol + n2] = 1
#mask[crow - n2:crow + n2, ccol-n:ccol+n] = 1
#mask[crow-n:crow+n, ccol-n2:ccol+n2] = 1


## Gaussian mask
gaussian = gaussianZero(50, 300, img)

f_filter = f * mask #* gaussian

magnitude = np.log(1 + np.abs(f_filter))

img_back = inverseFourier(f_filter)


printImg(magnitude, img_back)

# %%
i0 = drange(0.0, 2 * np.pi, 0.1)

rows, cols = img.shape
crow, ccol = rows // 2, cols // 2 # center row, center column

## Gaussian mask
gaussian = gaussianZero(50, 300, img)

f_filter = f * gaussian

magnitude = np.log(1 + np.abs(f_filter))

img_back = inverseFourier(f_filter)


printImg(magnitude, img_back)

# %%
rows, cols = img.shape
crow, ccol = rows // 2, cols // 2 # center row, center column

coords = magnitud>0.75*magnitud.max()

## Gaussian mask
#gaussian = gaussianZero(50, 300, img)

f_filter = f #* gaussian

temp = np.zeros((rows, cols))

for i in range(0, cols):
    for j in range(0, rows):
        if coords[j][i] == True:
            temp = temp + gaussianZero(1, 300, img, i, j)
            #f_filter[j][i] = 0
print(temp)
f_filter = f * temp
## Center correction
#n2 = 10
#mask = np.ones((rows, cols), np.uint8)
#mask[crow - n2 : crow + n2, ccol-n2 : ccol + n2] = 1
#f_filter = f_filter * mask
            
magnitude = np.log(1 + np.abs(f_filter))

img_back = inverseFourier(f_filter)


printImg(magnitude, img_back)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-c4a911848159> in <module>()
#      14     for j in range(0, rows):
#      15         if coords[j][i] == True:
# ---> 16             temp = temp + gaussianZero(1, 300, img, i, j)
#      17             #f_filter[j][i] = 0
#      18 print(temp)
#
# <ipython-input-50-06a0e7c49118> in gaussianZero(size, intensity, img, crow, ccol)
#      33     gaussian = x * x.T
#      34     mask2 = np.zeros((rows, cols))
# ---> 35     mask2[crow - size:crow + size, ccol-size:ccol+size] = gaussian
#      36     return mask2
#      37
#
# ValueError: could not broadcast input array from shape (2,2) into shape (0,2)
